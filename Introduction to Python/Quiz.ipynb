# %%
lst = [1, 1, 2, 2, 3, 4, 5]
lst.count(1)
# Out:
# 2

# %%
"string".find("z")
# Out:
# -1

# %%
lst
# Out:
# [1, 1, 2, 2, 3, 4, 5]

# %%
lst = [1, 2, 3, 4, 5]
lst[1:3]
# Out:
# [2, 3]

# %%
lst[1:3] = [6, 7, 8]

# %%
lst
# Out:
# [1, 6, 7, 8, 4, 5]

# %%
"Python"[::2]
# Out:
# 'Pto'

# %%
"Python"[1:4]
# Out:
# 'yth'

# %%
int(5.67)
# Out:
# 5

# %%
lst.find(6)
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[15], line 1
#
# ----> 1 lst.find(6)
#
#
#
# AttributeError: 'list' object has no attribute 'find'

# %%
lst.index(6)
# Out:
# 1

# %%
lst
# Out:
# [1, 6, 7, 8, 4, 5]

# %%
str
# Out:
# 'string'

# %%
str = "string"
str.combine(lst)
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[24], line 2
#
#       1 str = "string"
#
# ----> 2 str.combine(lst)
#
#
#
# AttributeError: 'str' object has no attribute 'combine'

# %%
lst.combine(str)
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[25], line 1
#
# ----> 1 lst.combine(str)
#
#
#
# AttributeError: 'list' object has no attribute 'combine'

# %%
lst.join(str)
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[26], line 1
#
# ----> 1 lst.join(str)
#
#
#
# AttributeError: 'list' object has no attribute 'join'

# %%
str.join(lst)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[29], line 1
#
# ----> 1 str.join(lst)
#
#
#
# TypeError: sequence item 0: expected str instance, int found

# %%
str.join(str(lst))
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[27], line 1
#
# ----> 1 str.join(str(lst))
#
#
#
# TypeError: 'str' object is not callable

# %%
str(123)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[21], line 1
#
# ----> 1 str(123)
#
#
#
# TypeError: 'str' object is not callable

# %%
"a".join(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 "a".join(lst)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
lst = [1, 2, 3]
str = "a"
str.join(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 lst = [1, 2, 3]
#       2 str = "a"
# ----> 3 str.join(lst)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
lst = ["abs", "def", "ghi"]
str = " a "
str.join(lst)
# Out:
# 'abs a def a ghi'
