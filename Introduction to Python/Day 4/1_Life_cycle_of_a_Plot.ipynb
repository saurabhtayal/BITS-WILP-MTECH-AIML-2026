# %% [markdown]
# <center> <img src ="https://i.postimg.cc/1X8H7YYt/BITS-Logo.png" width = "400" alt="BITS Pilani Logo" /> </center>

# %% [markdown]
# <font color='green'> <h1> <center> Life cycle of a Plot </center> </h1> </font>

# %% [markdown]
# Lets import the bike rental dataset and understand the life cycle of a plot with it.

# %% [markdown]
# - Prepare the data
# - Create the figure
# - Plot the graphs
# - Styling the plots
# - Save the plots

# %% [markdown]
# <b> Prepare the data <b>

# %%
import pandas as pd

# import numpy as np
import matplotlib.pyplot as plt

# %%
bikes = pd.read_csv("bike_shairing_hourly.csv")

# %%
bikes = pd.read_csv(
    "C:\\My_Stuff\\BITS WILP MTECH AIML 2026\\Introduction to Python\\Day 4\\bike_shairing_hourly.csv"
)

# %%
bikes = pd.read_csv(
    "C:\\My_Stuff\\BITS WILP MTECH AIML 2026\\Introduction to Python\\Day 4\\DAY_4_1\\bike_shairing_hourly.csv"
)

# %%
bikes.head(2)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40

# %% [markdown]
# <b> Create the figure<b>

# %% [markdown]
# Lets create an area where plots can be rendered. Its referred as figure.

# %%
figure = plt.figure()

# %% [markdown]
# Figure can have subplot in it which further holds the actual plot in it.

# %%
figure = plt.figure()
figure.add_subplot(1, 1, 1)
plot_casual_cnt = plt.plot(bikes.cnt)
plt.show()

# %% [markdown]
# <b> Plot the graphs <b>

# %% [markdown]
# Figure can have multiple plots in it.

# %%
figure = plt.figure()

figure.add_subplot(1, 1, 1)  # row, column, panel no
plot_casual_cnt = plt.plot(bikes.casual)

figure.add_subplot(1, 2, 1)  # row, column, panel no
plot_registered_cnt = plt.plot(bikes.registered)

plt.show()

# %% [markdown]
# Figure can hold multiple sub plots as well one below the other. Just need to appropriately set the subplots.

# %%
figure = plt.figure()

figure.add_subplot(2, 1, 1)
plot_casual_cnt = plt.plot(bikes.casual)

figure.add_subplot(2, 1, 2)
plot_registered_cnt = plt.plot(bikes.registered)

plt.show()

# %% [markdown]
# Another example

# %%
fig = plt.figure()

plot1 = fig.add_subplot(2, 2, 1)
plot1.plot(bikes.casual)

plot2 = fig.add_subplot(2, 2, 2)
plot2.plot(bikes.registered)

plot3 = fig.add_subplot(2, 2, 3)
plot3.plot(bikes.season.unique())

plot4 = fig.add_subplot(2, 2, 4)
plot4.plot(bikes.hr.unique())

plt.show()

# %% [markdown]
# <B> Styling the plots<b>

# %% [markdown]
# Lets apply some styles on the plots.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'petroff6',
#  'petroff8',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")

# %%
figure = plt.figure()

figure.add_subplot(2, 1, 1)
plot_casual_cnt = plt.plot(bikes.casual)

figure.add_subplot(2, 1, 2)
plot_registered_cnt = plt.plot(bikes.registered)

plt.show()

# %%
plt.style.use("grayscale")

# %%
figure = plt.figure()

figure.add_subplot(2, 1, 1)
plot_casual_cnt = plt.plot(bikes.casual)

figure.add_subplot(2, 1, 2)
plot_registered_cnt = plt.plot(bikes.registered)

plt.show()

# %% [markdown]
# <b> Save the plots <b>

# %%
figure = plt.figure()

figure.add_subplot(1, 1, 1)
plt_casual = plt.plot(bikes.casual)

plt.savefig("plt_casual.png")

# %% [markdown]
# Another example

# %%
figure = plt.figure()

figure.add_subplot(2, 1, 1)
plot_casual_cnt = plt.plot(bikes.casual)

figure.add_subplot(2, 1, 2)
plot_registered_cnt = plt.plot(bikes.registered)

plt.savefig("plt.png")

plt.show()
