# %%
length = eval(input("input the length in centimeter: "))
if length >= 0:
    print("The length in inches is:", length / 2.54)
else:
    print("Please enter a valid number for length in centimeter.")
# Out:
# The length in inches is: 3.937007874015748
