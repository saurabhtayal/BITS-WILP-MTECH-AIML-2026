# %% [markdown]
# <center> <img src ="https://i.postimg.cc/1X8H7YYt/BITS-Logo.png" width = "400" alt="BITS Pilani Logo" /> </center>

# %% [markdown]
# <font color='green'> <h1> <center> Python - Conditional Executions </center> </h1> </font>

# %% [markdown]
# Frequently the programs needs to follow a certain flow based on the fullfillment of certain condition. If something is true then follow some path otherwise follow another path.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Simple Example of guessing a number <b>

# %%
import random

#generate any random number between 1 to 10
number = random.randint(1,10)
#print(number)

guess = int(input("Enter an integer\n"))
if guess == number :
    print("Your guess is correct!")
else:
    print("Sorry, you failed to guess it!")
# Out:
# Enter an integer
#  4
# Sorry, you failed to guess it!

# %% [markdown]
# The syntax of if statement generally has the following form : <br>
#
#     if <condition> :
#         statements_to_be_executed_when_condition_is_true
#     else:
#         statements_to_be_executed_when_condition_is_false

# %% [markdown]
# Carefully look at the colons (:) placed after if and else statements. They are compulsary. Also look at the indentation applied at the if block statements and else block statements. The statements having same indendation will be considered as the part of same block. No curly braces or other symbols are used for the determination of the if and else blocks.

# %% [markdown]
# <b> Boolean Expression<b>

# %% [markdown]
# The expression that return true or false values as outcome are boolean expressions. == or != or other logical operators can be used withing boolean expression to frame the desired condition.

# %%
12 == 12  # returns true
# Out:
# True

# %%
12 == 13 # returns false
# Out:
# False

# %% [markdown]
# Always keep in mind the difference between = and == operator. = is assignment whereas == is conditional.

# %%
x = 5
y = 6

x = y  # this is assignment operator not conditional operator

# %% [markdown]
# <b> Comparison Operators<b>

# %%
x = 5
y = 6

# %%
x == y   # x is equal to y
# Out:
# False

# %%
x != y  # x is not equal to y
# Out:
# True

# %%
x > y  # x is greater than y
# Out:
# False

# %%
x < y # x is less than y
# Out:
# True

# %%
x >= y # x is greater than or equal to y
# Out:
# False

# %%
x <= y # x is less than or equal to y
# Out:
# True

# %%
x is y # x is same as y
# Out:
# False

# %%
x is not y # x is not same as y
# Out:
# True

# %% [markdown]
# <b> Logical Operators<b>

# %% [markdown]
# 'and', 'or' and 'not' are logical operators. They can be used while framing the complex conditions.

# %%
x = 5
y = 6

# %%
x > 4 and y > 5  # two conditions concatenanted , if both are true then only true will be returned
# Out:
# True

# %%
x > 4 or y < 3 # if any one of the condition is true, then will be returned otherwise false is returned
# Out:
# True

# %%
x > 14 or y > 3 # if any one of the condition is true, then will be returned otherwise false is returned
# Out:
# True

# %%
x < 4 or y < 3 # if any one of the condition is true, then will be returned otherwise false is returned
# Out:
# False

# %%
not(x < y ) # used to negate the value returned by conditional expression
# Out:
# False

# %% [markdown]
# # Conditional Execution

# %% [markdown]
# Conditional statements gives ability to change the flow of the program based on the conidtions specified in the statements.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The simple if statement can have only if block in it. That means , only if the condition is satisfied , then execute the statements in the if block otherwise ignore those statements.

# %%
number = int(input("Enter the number\n"))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number")
# Out:
# Enter the number
#  4
# 4  is even number

# %% [markdown]
# If block can consists of more than one statemenets. If the condition is satisfied all the statements in that block are executed. The statements having same indentation constitues the block.

# %%
number = int(input("Enter the number\n"))

if number % 2 == 0 :   # if block can consists of more than one statements, here two print statements are printed if condiotn is true
    print("You have entered ", number)
    print(number ," is even number")
# Out:
# Enter the number
#  2
# You have entered  2
# 2  is even number

# %% [markdown]
# One more exmaple

# %%
number = int(input("Enter the number\n"))

if number % 2 == 0 :   # if block can consists of more than one statements, here two print statements are printed if condiotn is true
    print("You have entered ", number)
    print(number ," is even number")

print("I am always printed!")    # this statement is always printed as its not part of if block, check the indentation
# Out:
# Enter the number
#  4
# You have entered  4
# 4  is even number
# I am always printed!

# %% [markdown]
# # Alternative Execution

# %% [markdown]
# But there will be situations where we have more than one branches of code that needs to be taken up based on the evaluation of the conditon. In that case, else statement and corresponding else block statements can be added.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
number = int(input("Enter the number\n"))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number")
else :
    print(number ," is odd number")
# Out:
# Enter the number
#  2
# 2  is even number

# %% [markdown]
# # Chained Conditionals

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Another exmaple of multiple branches :

# %%
mark = int(input("Enter the mark\n"))

if mark < 0 or mark > 100:
    print("Invalid marks are entered!")
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
elif mark >= 35 and mark < 80 :
    print("You passed in first class")
else :
    print("You got distinction!")
# Out:
# Enter the mark
#  80
# You got distinction!

# %% [markdown]
# # Nested Conditionals

# %% [markdown]
# One conditional can be nested within another conditional. For example :

# %%
number1 = int(input("Enter first number \n"))
number2 = int(input("Enter second number \n"))

if number1 == number2:
    print("Both numbers are same")
else:
    if number1 > number2:
        print("First number is bigger than second")
    else:
        print("First number is smaller than second")
# Out:
# Enter first number
#  5
# Enter second number
#  4
# First number is bigger than second

# %% [markdown]
# # Catching Exceptions with try and except

# %% [markdown]
# If while executing the code, error occured then execution of code is stopped and error trace is shown to the user. In order to handle that situation gracefully, the code that is expected to raise exception can be put inside a try block and the error can be handled without halting the further execution of the program.

# %% [markdown]
# For example, you are asking user to enter a number and he has entered the string. When accession this string value , error will be raised.

# %%
number = int(input("Enter a number\n")) # if number entered in string then it will throw error

if number % 2 == 0 :
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter a number
#  4
# Number is even

# %% [markdown]
# This can be handled with try block and user can be made aware about the actual thing that has happened.

# %%
try :
    number = int(input("Enter a number\n")) # if number entered in string then it will throw error

    if number % 2 == 0 :
        print("Number is even")
    else:
        print("Number is odd")
except:
    print("Seems you have entered a string value")
# Out:
# Enter a number
#  er
# Seems you have entered a string value

# %% [markdown]
# # Exercise

# %% [markdown]
# Q1. Write a program that asks user to enter a length in centimeters. If negative value is entered, the program should tell the user that the entry is invalid. Otherwise the program should convert the length to inches and print out the result. There are 2.54 centimeters in inches.

# %%
#Try it here

# %% [markdown]
# Q2. Write a program that accepts sentence from the user as input and then print the unique words present in that sentense along with the number of times they appeared in the sentence. Don't use any of the built in fuction or other data structure.

# %%
#Try it here

# %% [markdown]
# Q3.Write a program that accepts sentence from the user as input and then print the location of each vowel in the sentence.

# %%
#Try it here

# %% [markdown]
# Q4. Write a program that asks user to enter a word and determines whether the word is palindrome or not. A palindrome is a word
# that read the same backwards as forwards.

# %%
#Try it here

# %% [markdown]
# # Answer

# %%
#Q1 Solution

length_in_cm = input("Enter the lenght in centimeter\n")

try:
    length_in_cm = float(length_in_cm)

    if length_in_cm < 0 :
        print("You have entered negative value. ")
    else:
        length_in_inches = length_in_cm / 2.54
        print(length_in_cm, " cm = ", length_in_inches, " inches")
except:
    print("Seems you have not entered a number. ")
# Out:
# Enter the lenght in centimeter
# -4
# You have entered negative value.

# %%
#Q2 Solution

sentence = input('Enter the sentence\n')

list_of_words = sentence.split()
list_of_unique_words = []
list_of_count_of_unique_words = []

for word in list_of_words:
    if word not in list_of_unique_words:
        list_of_unique_words.append(word)
        list_of_count_of_unique_words.append(1)
    else:
        index = list_of_unique_words.index(word)
        count = int(list_of_count_of_unique_words[index])
        count = count + 1
        list_of_count_of_unique_words[index] = count

print("\n Word     Count")
for i in range(len(list_of_unique_words)):
    print(list_of_unique_words[i], "    ", list_of_count_of_unique_words[i])
# Out:
# Enter the sentence
# this is fine but also not fine
#
#  Word     Count
# this      1
# is      1
# fine      2
# but      1
# also      1
# not      1

# %%
#Q3 Solution
sentence = input('Enter the sentence\n')

vowel_list = ['a', 'e', 'i', 'o', 'u']

index = 0
for letter in sentence:
    if letter in vowel_list:
        print(letter, "present at location ", index)
    index = index + 1
# Out:
# Enter the sentence
# this is nice
# i present at location  2
# i present at location  5
# i present at location  9
# e present at location  11

# %%
#Q4 Solution

string = input("enter the word\n")

orig_string = list(string)
reversed_string = list(reversed(string))

is_palindrome = True
for i in range(len(orig_string)):
    if orig_string[i] != reversed_string[i]:
        is_palindrome = False

if is_palindrome:
    print('The string is palindrome')
else:
    print('The string is not palindrome')
# Out:
# enter the word
# katak
# The string is palindrome
# ['k', 'a', 't', 'a', 'k']
# ['k', 'a', 't', 'a', 'k']
