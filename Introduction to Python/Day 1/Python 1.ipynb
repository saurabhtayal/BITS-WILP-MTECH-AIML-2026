# %%
print("Hi there!")
# Out:
# Hi there!

# %%
i = 0
while i <= 1:
    print("Hi", i)
    i = i + 1
# Out:
# Hi 0
# Hi 1

# %%
import numpy as np
# import pandas as pd

# Create a clean AI matrix calculation
data = np.array([[1, 2], [3, 4]])
print("Matrix calculation verification:")
print(data * 4)
# Out:
# Matrix calculation verification:
# [[ 4  8]
#  [12 16]]

# %%
x=1
print( x )
# Out:
# 1

# %%
def test(x, y):
    print(x + y)

# %%
print('Single quotes also work!')
# Out:
# Single quotes also work!

# %%
print('multiline \n outputs also work')
# Out:
# multiline
#  outputs also work

# %%
print('abc','xyz')
# Out:
# abc xyz

# %%
print('3+4')
# Out:
# 3+4

# %%
print(3+4)
# Out:
# 7

# %%
print('abc', 'xyz', sep = "-") # changing default separator from space to hyphen
# Out:
# abc-xyz

# %%
print('abc') #default ending is newline
print('xyz')
# Out:
# abc
# xyz

# %%
print('abc', end = '-') #changing ending from newline to hyphen
print('xyz')
# Out:
# abc-xyz

# %%
print('*','**','***','****','*****',sep = '\n') # changing default separator from space to newline
# Out:
# *
# **
# ***
# ****
# *****

# %%
name = input("What is your name? ") # input function to take user input
print("Hello, " + name + "!") # print function to display a message with the user's name
# Out:
# Hello, Saurabh!
